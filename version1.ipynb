# %%
import pandas as pd
import xarray as xr
from netCDF4 import Dataset
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
file_qns = xr.open_dataset('C:/Users/19294/Documents/MesonetProject/datafiles/QUEE.nc')
qns_df = file_qns.to_dataframe()
qns_df
# Out:
#                       latitude  longitude  elevation    temp_2m  temp_9m  \
# time
# 2018-03-01 05:00:00  40.734337 -73.815857    54.5592  11.032970      NaN
# 2018-03-01 05:05:00  40.734337 -73.815857    54.5592  11.095240      NaN
# 2018-03-01 05:10:00  40.734337 -73.815857    54.5592  11.274160      NaN
# 2018-03-01 05:15:00  40.734337 -73.815857    54.5592  11.363660      NaN
# 2018-03-01 05:20:00  40.734337 -73.815857    54.5592  11.391750      NaN
# ...                        ...        ...        ...        ...      ...
# 2024-09-24 03:35:00  40.734337 -73.815857    54.5592  16.599680      NaN
# 2024-09-24 03:40:00  40.734337 -73.815857    54.5592  16.609810      NaN
# 2024-09-24 03:45:00  40.734337 -73.815857    54.5592  16.570910      NaN
# 2024-09-24 03:50:00  40.734337 -73.815857    54.5592  16.581249      NaN
# 2024-09-24 03:55:00  40.734337 -73.815857    54.5592  16.564390      NaN
#
#                      relative_humidity  solar_insolation
# time
# ...

# %%
file_manh = xr.open_dataset('C:/Users/19294/Documents/MesonetProject/datafiles/MANH.nc')
manh_df = file_manh.to_dataframe()
manh_df
# Out:
#                       latitude  longitude  elevation    temp_2m  temp_9m  \
# time
# 2018-03-01 05:00:00  40.767544 -73.964485  94.792801  14.388020      NaN
# 2018-03-01 05:05:00  40.767544 -73.964485  94.792801  13.927010      NaN
# 2018-03-01 05:10:00  40.767544 -73.964485  94.792801  14.151170      NaN
# 2018-03-01 05:15:00  40.767544 -73.964485  94.792801  14.065880      NaN
# 2018-03-01 05:20:00  40.767544 -73.964485  94.792801  14.186030      NaN
# ...                        ...        ...        ...        ...      ...
# 2024-09-24 03:35:00  40.767544 -73.964485  94.792801  16.858271      NaN
# 2024-09-24 03:40:00  40.767544 -73.964485  94.792801  16.693430      NaN
# 2024-09-24 03:45:00  40.767544 -73.964485  94.792801  16.624300      NaN
# 2024-09-24 03:50:00  40.767544 -73.964485  94.792801  16.739491      NaN
# 2024-09-24 03:55:00  40.767544 -73.964485  94.792801  16.764151      NaN
#
#                      relative_humidity  solar_insolation
# time
# ...

# %%
file_stb = xr.open_dataset('C:/Users/19294/Documents/MesonetProject/datafiles/STON.nc')
stb_df = file_stb.to_dataframe()
stb_df
# Out:
#                       latitude  longitude  elevation    temp_2m    temp_9m  \
# time
# 2018-03-01 05:00:00  40.919121 -73.131683    43.9217   8.874483   8.973778
# 2018-03-01 05:05:00  40.919121 -73.131683    43.9217   8.804246   8.920882
# 2018-03-01 05:10:00  40.919121 -73.131683    43.9217   8.802579   8.947894
# 2018-03-01 05:15:00  40.919121 -73.131683    43.9217   8.811733   8.966343
# 2018-03-01 05:20:00  40.919121 -73.131683    43.9217   8.778365   8.918861
# ...                        ...        ...        ...        ...        ...
# 2024-09-24 03:35:00  40.919121 -73.131683    43.9217  16.233191  16.129440
# 2024-09-24 03:40:00  40.919121 -73.131683    43.9217  16.207491  16.101830
# 2024-09-24 03:45:00  40.919121 -73.131683    43.9217  16.218019  16.099859
# 2024-09-24 03:50:00  40.919121 -73.131683    43.9217  16.258080  16.121269
# 2024-09-24 03:55:00  40.919121 -73.131683    43.9217  16.236750  16.115370
#
#                      relative_humidity  solar_insolation
# ...

# %%
file_sout = xr.open_dataset('C:/Users/19294/Documents/MesonetProject/datafiles/SOUT.nc')
sout_df = file_sout.to_dataframe()
sout_df
# Out:
#                       latitude  longitude  elevation    temp_2m    temp_9m  \
# time
# 2018-03-01 05:00:00  41.040081 -72.465866    8.93064   7.587285   7.702244
# 2018-03-01 05:05:00  41.040081 -72.465866    8.93064   7.718687   7.831253
# 2018-03-01 05:10:00  41.040081 -72.465866    8.93064   7.737968   7.861269
# 2018-03-01 05:15:00  41.040081 -72.465866    8.93064   7.735479   7.866156
# 2018-03-01 05:20:00  41.040081 -72.465866    8.93064   7.755234   7.911569
# ...                        ...        ...        ...        ...        ...
# 2024-09-24 03:35:00  41.040081 -72.465866    8.93064  15.224580  15.275390
# 2024-09-24 03:40:00  41.040081 -72.465866    8.93064  15.299440  15.345650
# 2024-09-24 03:45:00  41.040081 -72.465866    8.93064  15.181630  15.252670
# 2024-09-24 03:50:00  41.040081 -72.465866    8.93064  15.137940  15.208580
# 2024-09-24 03:55:00  41.040081 -72.465866    8.93064  15.162430  15.210120
#
#                      relative_humidity  solar_insolation
# ...

# %%
i = 166

print(stb_df['solar_insolation'].iloc[i])
stb_df.index[i]
# Out:
# 520.4296
# Timestamp('2018-03-01 18:50:00')

# %%
diff_data = manh_df - sout_df
diff_data['temp_2m'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
xdata = stb_df.index
ydata1 = stb_df['temp_2m'].iloc[:] # stony brook
ydata2 = qns_df['temp_2m'].iloc[:] # queens

ydata3 = manh_df['temp_2m'].iloc[:] # manhattan
ydata4 = sout_df['temp_2m'].iloc[:] # southold

plt.xlabel('year')
plt.ylabel('temp (C)')

#plt.plot(xdata, ydata3, color='blue')
#plt.plot(xdata, ydata4, color='orange')
plt.plot(xdata,diff_data['temp_2m'])
plt.show()
